# %%
pip install crewai groq
# Out:
# Requirement already satisfied: crewai in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.102.0)
# Collecting groq
#   Downloading groq-0.18.0-py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 8.8 MB/s eta 0:00:01
# Requirement already satisfied: json5>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (0.10.0)
# Requirement already satisfied: regex>=2024.9.11 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (2024.11.6)
# Requirement already satisfied: blinker>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (1.9.0)
# Requirement already satisfied: tomli-w>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (1.2.0)
# Requirement already satisfied: litellm==1.60.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (1.60.2)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (1.30.0)
# Requirement already satisfied: python-dotenv>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (1.0.1)
# Requirement already satisfied: jsonref>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (1.1.0)
# Requirement already satisfied: appdirs>=1.4.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (4.8.0)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (1.30.0)
# Requirement already satisfied: tomli>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (2.2.1)
# Requirement already satisfied: pdfplumber>=0.11.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (0.11.5)
# Requirement already satisfied: pydantic>=2.4.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (2.10.6)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (1.30.0)
# Requirement already satisfied: json-repair>=0.25.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (0.39.1)
# Requirement already satisfied: openpyxl>=3.1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (3.1.5)
# Requirement already satisfied: chromadb>=0.5.23 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (0.5.23)
# Requirement already satisfied: click>=8.1.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (8.1.8)
# Requirement already satisfied: instructor>=1.3.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (1.7.2)
# Requirement already satisfied: uv>=0.4.25 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (0.6.2)
# Requirement already satisfied: pyvis>=0.3.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (0.3.2)
# Requirement already satisfied: openai>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from crewai) (1.64.0)
# Requirement already satisfied: tokenizers in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from litellm==1.60.2->crewai) (0.19.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from litellm==1.60.2->crewai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from litellm==1.60.2->crewai) (0.7.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from litellm==1.60.2->crewai) (4.23.0)
# Requirement already satisfied: httpx<0.28.0,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from litellm==1.60.2->crewai) (0.27.2)
# Requirement already satisfied: aiohttp in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from litellm==1.60.2->crewai) (3.11.12)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from litellm==1.60.2->crewai) (3.1.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from groq) (4.6.2.post1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from groq) (4.12.2)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from groq) (1.3.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from groq) (1.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq) (3.7)
# Requirement already satisfied: requests>=2.32.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from auth0-python>=4.7.1->crewai) (2.32.3)
# Requirement already satisfied: urllib3>=2.2.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from auth0-python>=4.7.1->crewai) (2.3.0)
# Requirement already satisfied: cryptography>=43.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from auth0-python>=4.7.1->crewai) (44.0.1)
# Requirement already satisfied: pyjwt>=2.8.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from auth0-python>=4.7.1->crewai) (2.8.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp->litellm==1.60.2->crewai) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp->litellm==1.60.2->crewai) (1.4.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp->litellm==1.60.2->crewai) (4.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp->litellm==1.60.2->crewai) (2.4.6)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp->litellm==1.60.2->crewai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp->litellm==1.60.2->crewai) (1.18.3)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp->litellm==1.60.2->crewai) (23.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp->litellm==1.60.2->crewai) (0.3.0)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (0.7.6)
# Requirement already satisfied: tenacity>=8.2.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (9.0.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (3.15.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: tqdm>=4.65.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (4.66.4)
# Requirement already satisfied: typer>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (0.15.1)
# Requirement already satisfied: build>=1.0.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (1.2.2.post1)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (1.20.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (32.0.1)
# Requirement already satisfied: pypika>=0.48.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (0.48.9)
# Requirement already satisfied: grpcio>=1.58.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (1.70.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (4.2.1)
# Requirement already satisfied: overrides>=7.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (7.7.0)
# Requirement already satisfied: orjson>=3.9.12 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (3.10.15)
# Requirement already satisfied: fastapi>=0.95.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (0.115.8)
# Requirement already satisfied: numpy>=1.22.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (1.26.4)
# Requirement already satisfied: rich>=10.11.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (13.7.1)
# Requirement already satisfied: mmh3>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (5.1.0)
# Requirement already satisfied: importlib-resources in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: PyYAML>=6.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (6.0.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from chromadb>=0.5.23->crewai) (1.30.0)
# Requirement already satisfied: packaging>=19.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (24.2)
# Requirement already satisfied: pyproject_hooks in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (1.16.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (2.22)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb>=0.5.23->crewai) (0.45.3)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from importlib-metadata>=6.8.0->litellm==1.60.2->crewai) (3.21.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: jiter<0.9,>=0.6.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from instructor>=1.3.3->crewai) (0.7.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from instructor>=1.3.3->crewai) (2.27.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.60.2->crewai) (2.1.5)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (0.19.0)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (0.35.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (2023.12.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.8.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: google-auth>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.38.0)
# Requirement already satisfied: requests-oauthlib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.9)
# Requirement already satisfied: six>=1.9.0 in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.16.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.4.1)
# Requirement already satisfied: flatbuffers in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (24.3.25)
# Requirement already satisfied: coloredlogs in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (15.0.1)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.13.0)
# Requirement already satisfied: protobuf in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (5.29.3)
# Requirement already satisfied: et-xmlfile in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-api>=1.22.0->crewai) (1.2.18)
# Requirement already satisfied: wrapt<2,>=1.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai) (1.16.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.68.0)
# Requirement already satisfied: opentelemetry-proto==1.30.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.30.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.30.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: asgiref~=3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (3.8.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pdfplumber>=0.11.4->crewai) (4.30.1)
# Requirement already satisfied: Pillow>=9.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pdfplumber>=0.11.4->crewai) (10.1.0)
# Requirement already satisfied: pdfminer.six==20231228 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pdfplumber>=0.11.4->crewai) (20231228)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai) (3.3.2)
# Requirement already satisfied: monotonic>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (2.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pydantic>=2.4.2->crewai) (0.6.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from pyvis>=0.3.2->crewai) (8.9.0)
# Requirement already satisfied: networkx>=1.11 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyvis>=0.3.2->crewai) (3.3)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyvis>=0.3.2->crewai) (3.3.0)
# Requirement already satisfied: appnope in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.3)
# Requirement already satisfied: pygments>=2.4.0 in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.14.0)
# Requirement already satisfied: stack-data in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.5)
# Requirement already satisfied: traitlets>=5 in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.9.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.36)
# Requirement already satisfied: decorator in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.6)
# Requirement already satisfied: backcall in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tokenizers->litellm==1.60.2->crewai) (0.23.4)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.60.2->crewai) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.60.2->crewai) (2024.6.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (15.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.21.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (10.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (1.2.0)
# Requirement already satisfied: pure-eval in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/kakaogames/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.3.0)
# Installing collected packages: groq
# Successfully installed groq-0.18.0
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai

# Groq API 키 설정
openai.api_key = "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"

# 테스트 요청
try:
    response = openai.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "user", "content": "SM 30주년 관련 추천곡을 알려줘."}]
    )
    print(response.choices[0].message.content.strip())
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: Error code: 401 - {'error': {'message': 'Incorrect API key provided: gsk_wKU7********************************************xJAd. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
import litellm

# API 키 직접 설정
litellm.api_key = "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"  # 실제 API 키로 교체하세요

# 테스트 호출
try:
    response = litellm.completion(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": "useFetch 훅에 대해 간단히 요약해줘."}
        ],
        max_tokens=50
    )
    print(response.choices[0].message.content.strip())
except Exception as e:
    print(f"Error: {e}")
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# Error: litellm.AuthenticationError: AuthenticationError: OpenAIException - Error code: 401 - {'error': {'message': 'Incorrect API key provided: gsk_lb5L********************************************9gXe. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
from crewai import Agent, Task, Crew, LLM

# Initialize Large Language Model (LLM) of your choice (see all models on our Models page)
llm = LLM(model="groq/llama-3.1-70b-versatile")

# Create your CrewAI agents with role, main goal/objective, and backstory/personality
summarizer = Agent(
    role='Documentation Summarizer', # Agent's job title/function
    goal='Create concise summaries of technical documentation', # Agent's main objective
    backstory='Technical writer who excels at simplifying complex concepts', # Agent's background/expertise
    llm=llm, # LLM that powers your agent
    verbose=True # Show agent's thought process as it completes its task
)

translator = Agent(
    role='Technical Translator',
    goal='Translate technical documentation to other languages',
    backstory='Technical translator specializing in software documentation',
    llm=llm,
    verbose=True
)

# Define your agents' tasks
summary_task = Task(
    description='Summarize this React hook documentation:\n\nuseFetch(url) is a custom hook for making HTTP requests. It returns { data, loading, error } and automatically handles loading states.',
    expected_output="A clear, concise summary of the hook's functionality",
    agent=summarizer # Agent assigned to task
)

translation_task = Task(
    description='Translate the summary to Turkish',
    expected_output="Turkish translation of the hook documentation",
    agent=translator,
    dependencies=[summary_task] # Must run after the summary task
)

# Create crew to manage agents and task workflow
crew = Crew(
    agents=[summarizer, translator], # Agents to include in your crew
    tasks=[summary_task, translation_task], # Tasks in execution order
    verbose=True
)

result = crew.kickoff()
print(result)
# Out:
# ERROR:root:LiteLLM call failed: litellm.BadRequestError: GroqException - Missing API Key - A call is being made to LLM Provider but no key is set either in the environment variables ({LLM_PROVIDER}_API_KEY) or via params
# # Agent: Documentation Summarizer
# ## Task: Summarize this React hook documentation:
#
# useFetch(url) is a custom hook for making HTTP requests. It returns { data, loading, error } and automatically handles loading states.
#
#
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Provider List: https://docs.litellm.ai/docs/providers
#
#  Error during LLM call: litellm.BadRequestError: GroqException - Missing API Key - A call is being made to LLM Provider but no key is set either in the environment variables ({LLM_PROVIDER}_API_KEY) or via params
# ---------------------------------------------------------------------------
# OpenAILikeError                           Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/litellm/main.py:1549, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1547             optional_params[k] = v
# -> 1549     response = groq_chat_completions.completion(
#    1550         model=model,
#    1551         messages=messages,
#    1552         headers=headers,
#    1553         model_response=model_response,
#    1554         print_verbose=print_verbose,
#    1555         api_key=api_key,
#    1556         api_base=api_base,
#    1557         acompletion=acompletion,
#    1558         logging_obj=logging,
#    1559         optional_params=optional_params,
#    1560         litellm_params=litellm_params,
#    1561         logger_fn=logger_fn,
#    1562         timeout=timeout,  # type: ignore
#    1563         custom_prompt_dict=custom_prompt_dict,
#    1564         client=client,  # pass AsyncOpenAI, OpenAI client
#    1565         custom_llm_provider=custom_llm_provider,
#    1566         encoding=encoding,
#    1567     )
#    1568 elif custom_llm_provider == "aiohttp_openai":
#    1569     # NEW aiohttp provider for 10-100x higher RPS
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/litellm/llms/groq/chat/handler.py:55, in GroqChatCompletion.completion(self, model, messages, api_base, custom_llm_provider, custom_prompt_dict, model_response, print_verbose, encoding, api_key, logging_obj, optional_params, acompletion, litellm_params, logger_fn, headers, timeout, client, custom_endpoint, streaming_decoder, fake_stream)
#      53     fake_stream = False
# ---> 55 return super().completion(
#      56     model=model,
#      57     messages=messages,
#      58     api_base=api_base,
#      59     custom_llm_provider=custom_llm_provider,
#      60     custom_prompt_dict=custom_prompt_dict,
#      61     model_response=model_response,
#      62     print_verbose=print_verbose,
#      63     encoding=encoding,
#      64     api_key=api_key,
#      65     logging_obj=logging_obj,
#      66     optional_params=optional_params,
#      67     acompletion=acompletion,
#      68     litellm_params=litellm_params,
#      69     logger_fn=logger_fn,
#      70     headers=headers,
#      71     timeout=timeout,
#      72     client=client,
#      73     custom_endpoint=custom_endpoint,
#      74     streaming_decoder=streaming_decoder,
#      75     fake_stream=fake_stream,
#      76 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/litellm/llms/openai_like/chat/handler.py:248, in OpenAILikeChatHandler.completion(self, model, messages, api_base, custom_llm_provider, custom_prompt_dict, model_response, print_verbose, encoding, api_key, logging_obj, optional_params, acompletion, litellm_params, logger_fn, headers, timeout, client, custom_endpoint, streaming_decoder, fake_stream)
#     247 base_model: Optional[str] = optional_params.pop("base_model", None)
# --> 248 api_base, headers = self._validate_environment(
#     249     api_base=api_base,
#     250     api_key=api_key,
#     251     endpoint_type="chat_completions",
#     252     custom_endpoint=custom_endpoint,
#     253     headers=headers,
#     254 )
#     256 stream: bool = optional_params.pop("stream", None) or False
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/litellm/llms/openai_like/common_utils.py:30, in OpenAILikeBase._validate_environment(self, api_key, api_base, endpoint_type, headers, custom_endpoint)
#      29 if api_key is None and headers is None:
# ---> 30     raise OpenAILikeError(
#      31         status_code=400,
#      32         message="Missing API Key - A call is being made to LLM Provider but no key is set either in the environment variables ({LLM_PROVIDER}_API_KEY) or via params",
#      33     )
#      35 if api_base is None:
#
# OpenAILikeError: Missing API Key - A call is being made to LLM Provider but no key is set either in the environment variables ({LLM_PROVIDER}_API_KEY) or via params
#
# During handling of the above exception, another exception occurred:
#
# BadRequestError                           Traceback (most recent call last)
# Cell In[6], line 44
#      37 # Create crew to manage agents and task workflow
#      38 crew = Crew(
#      39     agents=[summarizer, translator], # Agents to include in your crew
#      40     tasks=[summary_task, translation_task], # Tasks in execution order
#      41     verbose=True
#      42 )
# ---> 44 result = crew.kickoff()
#      45 print(result)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/crew.py:576, in Crew.kickoff(self, inputs)
#     573 metrics: List[UsageMetrics] = []
#     575 if self.process == Process.sequential:
# --> 576     result = self._run_sequential_process()
#     577 elif self.process == Process.hierarchical:
#     578     result = self._run_hierarchical_process()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/crew.py:683, in Crew._run_sequential_process(self)
#     681 def _run_sequential_process(self) -> CrewOutput:
#     682     """Executes tasks sequentially and returns the final output."""
# --> 683     return self._execute_tasks(self.tasks)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/crew.py:781, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#     778     futures.clear()
#     780 context = self._get_context(task, task_outputs)
# --> 781 task_output = task.execute_sync(
#     782     agent=agent_to_use,
#     783     context=context,
#     784     tools=tools_for_task,
#     785 )
#     786 task_outputs.append(task_output)
#     787 self._process_task_result(task, task_output)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/task.py:302, in Task.execute_sync(self, agent, context, tools)
#     295 def execute_sync(
#     296     self,
#     297     agent: Optional[BaseAgent] = None,
#     298     context: Optional[str] = None,
#     299     tools: Optional[List[BaseTool]] = None,
#     300 ) -> TaskOutput:
#     301     """Execute the task synchronously."""
# --> 302     return self._execute_core(agent, context, tools)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/task.py:366, in Task._execute_core(self, agent, context, tools)
#     362 tools = tools or self.tools or []
#     364 self.processed_by_agents.add(agent.role)
# --> 366 result = agent.execute_task(
#     367     task=self,
#     368     context=context,
#     369     tools=tools,
#     370 )
#     372 pydantic_output, json_output = self._export_output(result)
#     373 task_output = TaskOutput(
#     374     name=self.name,
#     375     description=self.description,
#    (...)
#     381     output_format=self._get_output_format(),
#     382 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/agent.py:254, in Agent.execute_task(self, task, context, tools)
#     251 except Exception as e:
#     252     if e.__class__.__module__.startswith("litellm"):
#     253         # Do not retry on litellm errors
# --> 254         raise e
#     255     self._times_executed += 1
#     256     if self._times_executed > self.max_retry_limit:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/agent.py:243, in Agent.execute_task(self, task, context, tools)
#     240     task_prompt = self._use_trained_data(task_prompt=task_prompt)
#     242 try:
# --> 243     result = self.agent_executor.invoke(
#     244         {
#     245             "input": task_prompt,
#     246             "tool_names": self.agent_executor.tools_names,
#     247             "tools": self.agent_executor.tools_description,
#     248             "ask_for_human_input": task.human_input,
#     249         }
#     250     )["output"]
#     251 except Exception as e:
#     252     if e.__class__.__module__.startswith("litellm"):
#     253         # Do not retry on litellm errors
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:112, in CrewAgentExecutor.invoke(self, inputs)
#     109 except Exception as e:
#     110     if e.__class__.__module__.startswith("litellm"):
#     111         # Do not retry on litellm errors
# --> 112         raise e
#     113     else:
#     114         self._handle_unknown_error(e)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:102, in CrewAgentExecutor.invoke(self, inputs)
#      99 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     101 try:
# --> 102     formatted_answer = self._invoke_loop()
#     103 except AssertionError:
#     104     self._printer.print(
#     105         content="Agent failed to reach a final answer. This is likely a bug - please report it.",
#     106         color="red",
#     107     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:160, in CrewAgentExecutor._invoke_loop(self)
#     157 except Exception as e:
#     158     if e.__class__.__module__.startswith("litellm"):
#     159         # Do not retry on litellm errors
# --> 160         raise e
#     161     if self._is_context_length_exceeded(e):
#     162         self._handle_context_length()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:140, in CrewAgentExecutor._invoke_loop(self)
#     136     break
#     138 self._enforce_rpm_limit()
# --> 140 answer = self._get_llm_response()
#     141 formatted_answer = self._process_llm_response(answer)
#     143 if isinstance(formatted_answer, AgentAction):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:210, in CrewAgentExecutor._get_llm_response(self)
#     205 except Exception as e:
#     206     self._printer.print(
#     207         content=f"Error during LLM call: {e}",
#     208         color="red",
#     209     )
# --> 210     raise e
#     212 if not answer:
#     213     self._printer.print(
#     214         content="Received None or empty response from LLM call.",
#     215         color="red",
#     216     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:201, in CrewAgentExecutor._get_llm_response(self)
#     199 """Call the LLM and return the response, handling any invalid responses."""
#     200 try:
# --> 201     answer = self.llm.call(
#     202         self.messages,
#     203         callbacks=self.callbacks,
#     204     )
#     205 except Exception as e:
#     206     self._printer.print(
#     207         content=f"Error during LLM call: {e}",
#     208         color="red",
#     209     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/crewai/llm.py:291, in LLM.call(self, messages, tools, callbacks, available_functions)
#     288 params = {k: v for k, v in params.items() if v is not None}
#     290 # --- 2) Make the completion call
# --> 291 response = litellm.completion(**params)
#     292 response_message = cast(Choices, cast(ModelResponse, response).choices)[
#     293     0
#     294 ].message
#     295 text_response = response_message.content or ""
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/litellm/utils.py:1154, in client.<locals>.wrapper(*args, **kwargs)
#    1150 if logging_obj:
#    1151     logging_obj.failure_handler(
#    1152         e, traceback_exception, start_time, end_time
#    1153     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1154 raise e
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/litellm/utils.py:1032, in client.<locals>.wrapper(*args, **kwargs)
#    1030         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1031 # MODEL CALL
# -> 1032 result = original_function(*args, **kwargs)
#    1033 end_time = datetime.datetime.now()
#    1034 if "stream" in kwargs and kwargs["stream"] is True:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/litellm/main.py:3068, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    3065     return response
#    3066 except Exception as e:
#    3067     ## Map to OpenAI Exception
# -> 3068     raise exception_type(
#    3069         model=model,
#    3070         custom_llm_provider=custom_llm_provider,
#    3071         original_exception=e,
#    3072         completion_kwargs=args,
#    3073         extra_kwargs=kwargs,
#    3074     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2201, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2199 if exception_mapping_worked:
#    2200     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2201     raise e
#    2202 else:
#    2203     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:381, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     379 if original_exception.status_code == 400:
#     380     exception_mapping_worked = True
# --> 381     raise BadRequestError(
#     382         message=f"{exception_provider} - {message}",
#     383         llm_provider=custom_llm_provider,
#     384         model=model,
#     385         response=getattr(original_exception, "response", None),
#     386         litellm_debug_info=extra_information,
#     387     )
#     388 elif original_exception.status_code == 401:
#     389     exception_mapping_worked = True
#
# BadRequestError: litellm.BadRequestError: GroqException - Missing API Key - A call is being made to LLM Provider but no key is set either in the environment variables ({LLM_PROVIDER}_API_KEY) or via params
